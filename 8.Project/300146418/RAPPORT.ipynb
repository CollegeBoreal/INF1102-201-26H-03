# %% [markdown]
# # Rapport TP IaC – OpenTofu & Proxmox
#
# ## Étudiante
# Ikram Sidhoum
# 300146418

# %% [markdown]
# ## Objectif
# Déployer automatiquement une machine virtuelle Ubuntu avec NGINX.

# %% [markdown]
# ## Technologies
# - OpenTofu
# - Proxmox
# - Ubuntu
# - NGINX

# %%
print("Site disponible à : http://10.7.237.210")
