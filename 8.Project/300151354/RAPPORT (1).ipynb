# %% [markdown]
# # Rapport Monitoring Web
#
# Ce projet permet de tester un site web afin de vérifier s’il fonctionne correctement et mesurer son temps de réponse.
#
#
# ## Étudiant
#
# **Nom :** Makoudi Massinissa
# **Identifiant :** 300151354
# **Cours :** INF1102 -- Programmation système
#
# ---
# ## Thème du projet
#
# **Thème :** Monitoring Web – Analyse du temps de réponse d’un site web
#
# ## Objectif du projet
#
# L’objectif de ce projet est de vérifier la disponibilité d’un site web et de mesurer son temps de réponse.
#
# Pour cela :
# - Un script PowerShell envoie une requête HTTP vers un site web
# - Les données sont enregistrées dans un fichier JSON
# - Un script Python analyse ces données
# - Un graphique est généré pour visualiser les performances du site
#
# Ce projet permet de mieux comprendre la surveillance des services web et l’analyse des performances.

# %%
import json

with open("data/result.json") as f:
    data = json.load(f)

data
# Out:
# {'url': 'https://www.google.com', 'status': 200, 'time': 688.0782}

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.1 MB 20.8 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 23.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 21.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 16.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------- ----------------------- 5.0/12.3 MB 25.2 MB/s eta 0:00:01
#    -------------------------------- ------- 10.0/12.3 MB 23.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 20.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
# ...

# %%
import sys
print(sys.executable)
# Out:
# C:\tools\miniforge3\python.exe

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import sys
print(sys.executable)
# Out:
# C:\tools\miniforge3\python.exe

# %%
import sys
# !{sys.executable} -m pip install --user matplotlib

# %%
import json

with open("data/result.json") as f:
    data = json.load(f)

# %%
values = [650, 700, 680, 690, data["time"]]

plt.plot(values, marker='o')
plt.title("Evolution du temps de réponse")
plt.ylabel("Temps (ms)")
plt.xlabel("Test")
plt.grid()

plt.show()

# %% [markdown]
# ## Conclusion
#
# Ce projet a permis de mettre en place un système simple de monitoring web.
#
# Nous avons utilisé PowerShell pour récupérer les données d’un site web, puis Python pour analyser ces données et générer des visualisations.
#
# Les résultats montrent que le site testé est accessible avec un temps de réponse stable et acceptable.
#
# Ce projet permet de mieux comprendre le fonctionnement des requêtes HTTP, le traitement des données et la visualisation avec des graphiques.
#
# Il peut être amélioré en effectuant plusieurs tests automatiques sur une longue période afin d’obtenir une analyse plus précise des performances.

# %%
nom = "Makoudi Massinissa"
id_etudiant = 300151354

print("Nom :", nom)
print("Identifiant :", id_etudiant)
# Out:
# Nom : Makoudi Massinissa
# Identifiant : 300151354
