# %%
# Script Python pour afficher le nom et le numéro étudiant

nom = "Babatundé Adissa Fadolle AROUNA"
numero_etudiant = "300151970"

print("Nom :", nom)
print("Numéro étudiant :", numero_etudiant)
