# %% [markdown]
# 300138205

# %%
print ('bonjour taylor')
# Out:
# bonjour taylor

# %% [markdown]
# f(x) = \int_{a}^{x} g(t)\, dt

# %% [markdown]
# une somme

# %% [markdown]
# S(n) = \sum_{k=0}^{n} k^2

# %% [markdown]
# S(n) = \sum_{k=0}^{n} k^2
